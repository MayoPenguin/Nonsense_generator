# %% [markdown]
# # Project Description

# %% [markdown]
# Write a brief description of your project here.
#
# Note that projects should be self-sufficient, so make sure to provide enough information and context here for someone to understand what you are doing in your project, and why.
#
# _One day, my CSE friend sent me a paragraph about creativity. I carefully read through it and thought it makes sense. Although this paragraph did not seems like university-level writing, the logic and the reasoning were very clear, so I thought he wrote it himself. However, later he told me actually that paragraph was generated by GPT-3 from OpenAi. I was totally shocked because it seems at that moment I cannot distinguish whom I was talking to--a person or a machine? Did it mean GPT-3 passed the Turing test?_
#
# _Initially, I wanted to make a project by using GPT-2 or GPT-3. I looked at a bunch of tutorials online about how to install it, how to train it, and how to use it to pretend to be a human. I tried my best to understand the code used in those tutorials to train the GPT model, but I can only understand a few of them. However--I really don't want to admit that--I got stuck during the installing process. It seems to actually run the GPT model need a bunch of other stuff like TensorFlow. I tried several times but still failed to install TensorFlow._
#
# _After giving up the idea about GPT model, I kept browsing Github and found an interesting project called "BullshitGenerator". In the Chinese version, it will generate a seemly decent essay when you input a keyword and the length. After reviewing the code, I found the logic behind this generator is very simple, and I was really inspired by the idea to use the .replace method to insert the keyword into the essay template._
#
# _I still remember that when I studied for the TOEFL test, my teacher will give me some templates to use for the writing part; and back in junior high school when I have not yet decided to study abroad, the English teacher told me that the English essays which earn a high grade in the test are essentially same. I feel that my nonsense_generator will be perfect for generating such type of essay--although it sounds incredible, under certain conditions, you will need the essay like the one generated by my nonsense_generator. Based on the project on Github, I began to improve and write my own nonsense_generator. In nonsense_generator, you can customize not only the keyword and the length but also the paragraph and the type of article you want! My purpose for this project is to generate an essay in a quick, convenient, and customized way: if you need to write 60000 words in one hour for some unreasonable requests, come to the nonsense generator! Moreover, during that process, it also requires me to explore and summarize the commonplace of human language._

# %% [markdown]
# ## Project Code
#
# If it makes sense for your project, you can have code and outputs here in the notebook as well.

# %%
from my_module.functions import nonsense_generator

# %%
# Do a bunch of things.
nonsense_generator(keyword = '', length = , paragraph = , genre = '')
#please enter following input parameter:
#keyword as string;
#length as integer;
#paragraph as integer besides 0;
#genre as either string letter or essay.

# %%
# test it out
from my_module.test_functions import test_introduction_maker, test_content_filler, test_conclusion_creator, test_nonsense_generator
test_introduction_maker()
test_content_filler()
test_conclusion_creator() 
test_nonsense_generator()

# %% [markdown]
# #### Extra Credit (*optional*)
#
# Replace all of this text with a brief explanation (~3 sentences) of:
# 1. Your Python Background
# 2. How your project went above and beyond the requirements of the project and/or how you challenged yourself to learn something new with the final project

# %% [markdown]
# _1. I haven't been previsouly exposed to any language of coding; the only course I took which has something to do with coding is COGS8, but I droped it after the second week(becasue we are required to make a project and I have no idea what&how to do)._
#
# _2.During the coding, the biggest problem I met is how to customize the paragraph: where to segment; how to segment in python. Finally, I used an independent counter to solve those problems. Furthermore, I self-learn the JSON and use it to store data._
#
# _The problem of my nonsense_generator is very clear: grammar. Since all the sentence segments are pre-determined, python will not follow the grammar rule when randomly combining segments into a complete sentence, and the lower/upper case is also the problem._
#
# My future plan is keeping revising this nonsense_generator:
# 1. set up certain grammar rule for python to follow when generating sentences;
# 2. use other objects to store data rather than list;
# 3. further subdivide the topic of each list & you can customize the topic of the essay generated; for example, if you want to generate an essay about math, nonsense_generator will have priority for those sentence segments about math in the data;
# 4. I want the users of nonsense_generator can input the sentence which they want to appear in the article generated by themself;
# 5. I will make the introduction and conclusion more distinguished and featured;
# 6. in the future, nonsense_generator will be able to generator much more types of the article;
# 7. maybe one day, the nonsense_generator will become sense_generator:)
